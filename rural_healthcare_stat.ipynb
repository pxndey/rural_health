# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
#         print(os.path.join(dirname, filename))
        pass
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df_1 = pd.read_csv('/kaggle/input/rural-health-statistics-india2005-2019-2020/rhs_2005.csv')
df_2 = pd.read_csv('/kaggle/input/rural-health-statistics-india2005-2019-2020/rhs_2019.csv')

# %%
df_1.head()
# Out:
#             State/UT SubCenters  PHCs CHCs ANM/Health_Worker_Female Doctors  \
# 0     Andhra Pradesh      12522  1570  164                    13740    2137
# 1  Arunachal Pradesh        379    85   31                      454      78
# 2              Assam       5109   610  100                     5719     NaN
# 3              Bihar      10337  1648  101                      NaN     NaN
# 4       Chhattisgarh       3818   517  116                     3667     628
#
#   Specialists Radiographers Pharmacists LabTechinicians NursingStaff
# 0         224           140        1637            1437         2053
# 1           0            22          31              18          105
# 2         NaN           NaN         NaN             NaN          NaN
# 3         NaN           NaN         NaN             NaN          NaN
# 4          18            95         467             348          540

# %%
df_1
# Out:
#                 State/UT SubCenters   PHCs  CHCs ANM/Health_Worker_Female  \
# 0         Andhra Pradesh      12522   1570   164                    13740
# 1      Arunachal Pradesh        379     85    31                      454
# 2                  Assam       5109    610   100                     5719
# 3                  Bihar      10337   1648   101                      NaN
# 4           Chhattisgarh       3818    517   116                     3667
# 5                    Goa        172     19     5                      179
# 6                Gujarat       7274   1070   272                     6508
# 7                Haryana       2433    408    72                     2818
# 8       Himachal Pradesh       2068    439    66                     1790
# 9              Jharkhand       4462    561    47                      NaN
# 10             Karnataka       8143   1681   254                     8544
# 11                Kerala       5094    911   106                     5565
# ...

# %%
df_1=df_1.drop([34,23],axis=0)

# %%
df_1.isnull().sum()

# %%
df_1.fillna(0, inplace=True)

# %%
for column in df_1.columns:
    if column!='State/UT':
        df_1[column] = df_1[column].astype(int)

# %%
df_1.isnull().sum()

# %%
df_1.head()

# %%
df_1.info()

# %%
df1 = df_1.drop(37,axis=0)

# %%
df_1['LabTechnicians'] = df_1['LabTechinicians']
df_1 = df_1.drop('LabTechinicians',axis=1)

# %%
var = 'Doctors'
sorted_df = df1.sort_values(var, ascending=False)
sorted_df = sorted_df[sorted_df[var]<=20]
plt.bar(sorted_df['State/UT'], sorted_df[var])
plt.xticks(rotation=90)
plt.xlabel('State/UT')
plt.ylabel(var)
plt.ylim(0,20)
plt.show()

# %%
var = 'Specialists'
sorted_df = df1.sort_values(var, ascending=False)
sorted_df = sorted_df[sorted_df[var]<=20]
plt.bar(sorted_df['State/UT'], sorted_df[var])
plt.xticks(rotation=90)
plt.xlabel('State/UT')
plt.ylabel(f'{var}')
plt.ylim(0,20)
plt.show()

# %%
var = 'LabTechnicians'
sorted_df = df1.sort_values(var, ascending=False)
sorted_df = sorted_df[sorted_df[var]<=20]
plt.bar(sorted_df['State/UT'], sorted_df[var])
plt.xticks(rotation=90)
plt.xlabel('State/UT')
plt.ylabel(f'{var}')
plt.ylim(0,20)
plt.show()

# %%
var = 'Pharmacists'
sorted_df = df1.sort_values(var, ascending=False)
sorted_df = sorted_df[sorted_df[var]<=20]
plt.bar(sorted_df['State/UT'], sorted_df[var])
plt.xticks(rotation=90)
plt.xlabel('State/UT')
plt.ylabel(f'{var}')
plt.ylim(0,20)
plt.show()

# %%
df_2

# %%
df_2 = df_2.drop([34,37],axis=0)

# %%
df_2

# %%
df_2.info()

# %%
df_2.isnull().sum()

# %%
for column in df_2.columns:
    if column!='State/UT':
        df_2[column] = df_2[column].astype(int)

# %%
df_2.info()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.scatter(df_1['State/UT'], df_1[var], label='2005')
plt.scatter(df_2['State/UT'], df_2[var], label='2019')

plt.xlabel('States')
plt.ylabel(f'Number of {var}')
plt.title('2005 Vs 2019')
plt.ylim(0,2000)
plt.xticks(rotation=90)
plt.legend()

plt.show()

# %%
var = 'Specialists'
plt.figure(figsize=(16, 6))

plt.scatter(df_1['State/UT'], df_1[var], label='2005')
plt.scatter(df_2['State/UT'], df_2[var], label='2019')

plt.xlabel('States')
plt.ylabel(f'Number of {var}')
plt.title('2005 Vs 2019')
plt.ylim(0,1100)
plt.xticks(rotation=90)
plt.legend()

plt.show()

# %%
var = 'LabTechnicians'
plt.figure(figsize=(16, 6))

plt.scatter(df_1['State/UT'], df_1[var], label='2005')
plt.scatter(df_2['State/UT'], df_2[var], label='2019')

plt.xlabel('States')
plt.ylabel(f'Number of {var}')
plt.title('2005 Vs 2019')
plt.ylim(0,1100)
plt.xticks(rotation=90)
plt.legend()

plt.show()

# %%
var = 'Pharmacists'
plt.figure(figsize=(16, 6))

plt.scatter(df_1['State/UT'], df_1[var], label='2005')
plt.scatter(df_2['State/UT'], df_2[var], label='2019')

plt.xlabel('States')
plt.ylabel(f'Number of {var}')
plt.title('2005 Vs 2019')
plt.ylim(0,1100)
plt.xticks(rotation=90)
plt.legend()

plt.show()
